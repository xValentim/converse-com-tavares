# %%
from langchain_openai import OpenAIEmbeddings
from langchain.schema import Document
import matplotlib.pyplot as plt
from tqdm import tqdm

import pandas as pd
import numpy as np
from dotenv import load_dotenv
import json
import time
import os
load_dotenv()

df = pd.read_csv('../data/content_splitted_canal_tavares.csv')
df_embeddings = pd.read_csv('../data/embeddings_splitted_canal_tavares.csv')

embeddings_size = 3072
embeddings_model = 'text-embedding-3-large'
embeddings = OpenAIEmbeddings(model=embeddings_model)

# %%
X, y = df_embeddings, None

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# %%
plt.scatter(X_tsne[:, 0], X_tsne[:, 1])
plt.axis('off')
# Out:
# (-45.81421813964844, 46.490159606933595, -24.31778039932251, 33.989195728302)
